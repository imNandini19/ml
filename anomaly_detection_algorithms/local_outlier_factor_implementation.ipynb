# %%
from sklearn.neighbors import LocalOutlierFactor
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X = np.array([
    [1, 2],
    [2, 3],
    [2, 2],
    [8, 7],
    [7, 8],
    [100, 100]
])

# %%
plt.scatter(X[:,0], X[:,1], c=labels)

# %%
lof = LocalOutlierFactor(
    n_neighbors=20,
    contamination=0.1
)

# %%
labels = lof.fit_predict(X)
scores = lof.negative_outlier_factor_
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_lof.py:282: UserWarning: n_neighbors (20) is greater than the total number of samples (6). n_neighbors will be set to (n_samples - 1) for estimation.
#   warnings.warn(

# %%
print("Predicted labels:", labels)
print("\nAnomaly scores (lower = more anomalous):")
print(scores)
# Out:
# Predicted labels: [1 1 1 1 1 1]
#
# Anomaly scores (lower = more anomalous):
# [-0.99442593 -0.99691946 -0.99567588 -1.00938706 -1.00938706 -0.99442593]
